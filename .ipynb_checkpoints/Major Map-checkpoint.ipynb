# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import nltk
import re #regex

# %% [markdown]
# Eventually create a list of major codes and run a for loop to get all dataframes

# %%
def extract_course_catalog_info(dept): #where dept is a string
    site_url = 'https://www.ucsd.edu/catalog/courses/' + dept + '.html'
    page = requests.get(site_url)
    soup = BeautifulSoup(page.content, 'html.parser')

# %%
#site_url = 'https://www.ucsd.edu/catalog/courses/' + 'dept' + '.html'

dept = 'MATH'
site_url = 'https://www.ucsd.edu/catalog/courses/MATH.html'
page = requests.get(site_url)
soup = BeautifulSoup(page.content, 'html.parser')

#https://stackoverflow.com/questions/49010813/how-to-find-a-particular-class-in-beautifulsoup-using-findall

# %% [markdown]
# # Looking at just names and descriptions w/ htmlclass separation

# %%
#full_list = soup.find_all("p", {"class": "anchor-parent"}) 

names = soup.find_all("p", {"class": "course-name"})
descriptions = soup.find_all("p", {"class": "course-descriptions"}) #includes prereqs (so want to extract that)

# %%
name_list = [] #this is in HTML contains all course header info

for x in names:
    name_list.append(str(x))

# %%
course_ids = []
course_names = []
course_units = [] 

for n in np.arange(len(name_list) - 1):
    #for i in np.arange(len(name_list[n]) - 1):
    x = name_list[n]
    course_ids.append(x[len('<p class="course-name">') + len(dept) + 1 : x.index('.')])
    course_names.append(x[x.index('.')+2:len(x)-8])
    course_units.append(x[len(x)-6])

# %% [markdown]
# ## Some course names are weird (why?) e.g. 'Foundations\n\t\t  of Teaching and Learning Mathematics I'

# %% [markdown]
# ## Course units cut off (why?)

# %%
course_nums = []

for i in course_ids:
    course_nums.append(re.findall(r'\d+|\D+', i)) #regex makes id's in format 'Num' + 'Letter'    

#regex for this \d+|\D+

# just nums: r'^\d+'

# %% [markdown]
# #### use list comprehension it is cleaner
#
# finding indices of class category

# %%
for i in course_nums:
    if len(i[0]) == 2:
        try:
            lower_div_i = course_ids.index(i[0]+i[1]) #last index of lower divisions
        except IndexError:
            lower_div_i = course_ids.index(i[0])
    if int(i[0]) < 200:
        try:
            upper_div_i = course_ids.index(i[0]+i[1]) #" " of upper divisions
        except IndexError:
            upper_div_i = course_ids.index(i[0])
        
#[i for i,val in enumerate(l) if val==]

# %% [markdown]
# https://stackoverflow.com/questions/6294179/how-to-find-all-occurrences-of-an-element-in-a-list

# %% [markdown]
# ### How to find last value before 200

# %%
#converting description blocks into lists

desc_list = []
for i in descriptions:
    desc_list.append(re.findall(r"\w+,*", str(i)))

# %%
# Removing graduate courses

course_ids = course_ids[0:upper_div_i + 1]
course_names = course_names[0:upper_div_i + 1]
course_units = course_units[0:upper_div_i + 1]
desc_list = desc_list[0:upper_div_i + 1]

# %%
#extracting prerequisites.  

prereq_list = []

for i in np.arange(len(desc_list)):
    x = desc_list[i]
    try: 
        prereq_list.append(x[x.index('Prerequisites')+2:len(x)-1])
    except ValueError:
        print('prereq extraction error at index', i) 
        prereq_list.append('None')

# %%
prereq_list
# Out:
# [['Math', 'Placement', 'Exam', 'qualifying', 'score'],
#  ['Math', 'Placement', 'Exam', 'qualifying', 'score'],
#  ['Math',
#   'Placement',
#   'Exam',
#   'qualifying',
#   'score',
#   'or',
#   'MATH',
#   '3C',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['Math',
#   'Placement',
#   'Exam',
#   'qualifying',
#   'score,',
#   'or',
#   'AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '2,',
#   'or',
#   'SAT',
#   'II',
#   'Math',
#   'Level',
#   '2',
#   'score',
#   'of',
#   '600',
#   'or',
#   'higher,',
#   'or',
#   'MATH',
#   '3C,',
#   'or',
#   'MATH',
#   '4C'],
#  ['AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '3,',
#   '4,',
#   'or',
#   '5',
#   'or',
#   'equivalent',
#   'AB',
#   'subscore',
#   'on',
#   'BC',
#   'exam',
#   'or',
#   'MATH',
#   '10A,',
#   'or',
#   'MATH',
#   '20A'],
#  ['AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '3,',
#   '4,',
#   'or',
#   '5,',
#   'or',
#   'MATH',
#   '10B,',
#   'or',
#   'MATH',
#   '20B'],
#  ['span',
#   'AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '3,',
#   '4,',
#   'or',
#   '5,',
#   'or',
#   'MATH',
#   '10B',
#   'or',
#   'MATH',
#   '20B'],
#  ['CSE',
#   '8B',
#   'or',
#   'CSE',
#   '11',
#   'Prerequisite',
#   'courses',
#   'must',
#   'be',
#   'completed',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['Math',
#   'Placement',
#   'Exam',
#   'qualifying',
#   'score,',
#   'or',
#   'AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '2,',
#   'or',
#   'SAT',
#   'II',
#   'Math',
#   'Level',
#   '2',
#   'score',
#   'of',
#   '600',
#   'or',
#   'higher,',
#   'or',
#   'MATH',
#   '3C,',
#   'or',
#   'MATH',
#   '4C,',
#   'or',
#   'MATH',
#   '10A,',
#   'or',
#   'MATH',
#   '20A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['Math',
#   'Placement',
#   'Exam',
#   'qualifying',
#   'score,',
#   'or',
#   'AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '3',
#   'or',
#   'equivalent',
#   'AB',
#   'subscore',
#   'on',
#   'BC',
#   'exam',
#   'or',
#   'SAT',
#   'II',
#   'MATH',
#   '2C',
#   'score',
#   'of',
#   '650',
#   'or',
#   'higher,',
#   'or',
#   'MATH',
#   '4C',
#   'or',
#   'MATH',
#   '10A'],
#  ['AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '4',
#   'or',
#   '5,',
#   'or',
#   'AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '3,',
#   'or',
#   'MATH',
#   '20A',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better,',
#   'or',
#   'MATH',
#   '10B',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better,',
#   'or',
#   'MATH',
#   '10C',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '4',
#   'or',
#   '5,',
#   'or',
#   'MATH',
#   '20B',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['MATH',
#   '20C',
#   'or',
#   'MATH',
#   '21C',
#   'or',
#   'MATH',
#   '31BH',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'and',
#   'MATH',
#   '20C',
#   'or',
#   'MATH',
#   '21C',
#   'or',
#   'MATH',
#   '31BH',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'C',
#   'or',
#   'better'],
#  ['AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '5',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '31AH',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'B',
#   'or',
#   'better,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '31BH',
#   'with',
#   'a',
#   'grade',
#   'of',
#   'B',
#   'or',
#   'better,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['none'],
#  ['none'],
#  ['AP',
#   'Calculus',
#   'AB',
#   'score',
#   'of',
#   '4',
#   'or',
#   'more,',
#   'or',
#   'AP',
#   'Calculus',
#   'BC',
#   'score',
#   'of',
#   '3',
#   'or',
#   'more,',
#   'or',
#   'MATH',
#   '20A'],
#  ['Must',
#   'be',
#   'of',
#   'first',
#   'year',
#   'standing',
#   'and',
#   'a',
#   'Regent',
#   's',
#   'Scholar'],
#  ['MATH', '31CH', 'or', 'MATH', '109', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '100A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '100B', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '31CH', 'or', 'MATH', '109', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '103A', 'or', 'MATH', '100A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '100B',
#   'or',
#   'MATH',
#   '103B',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisite',
#   's',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '104A', 'or', 'consent', 'of', 'instructor'],
#  ['Math', '104B', 'or', 'consent', 'of', 'instructor'],
#  ['strong',
#   'MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '100B',
#   'or',
#   'MATH',
#   '103B',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'and',
#   'MATH',
#   '20D',
#   'and',
#   'MATH',
#   '20E',
#   'or',
#   'MATH',
#   '31CH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '20D,',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '109',
#   'or',
#   'MATH',
#   '31CH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '111A', 'or', 'consent', 'of', 'instructor'],
#  ['strong',
#   'MATH',
#   '11',
#   'or',
#   'MATH',
#   '180A',
#   'or',
#   'MATH',
#   '183',
#   'or',
#   'MATH',
#   '186,',
#   'and',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20D,',
#   'and',
#   'BILD',
#   '1',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '112A',
#   'and',
#   'MATH',
#   '110',
#   'and',
#   'MATH',
#   '180A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '180A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['span',
#   'MATH',
#   '20E',
#   'or',
#   'MATH',
#   '31CH,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '120A', 'or', 'consent', 'of', 'instructor'],
#  ['EDS', '30', 'MATH', '95,', 'Calculus', '10C', 'or', '20C'],
#  ['EDS', '121A', 'MATH', '121A'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'and',
#   'MATH',
#   '20D',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor',
#   'p',
#   'class',
#   'anchor',
#   'parent',
#   'a',
#   'class',
#   'anchor',
#   'id',
#   'math140a',
#   'name',
#   'math140a',
#   'a',
#   'p'],
#  ['MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '140A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '140B', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '142A',
#   'or',
#   'MATH',
#   '140A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '140B',
#   'or',
#   'MATH',
#   '142B',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisite',
#   's',
#   'may',
#   'enroll',
#   'with',
#   'the',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '140B',
#   'or',
#   'MATH',
#   '142B',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisite',
#   's',
#   'may',
#   'enroll',
#   'with',
#   'the',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '140B',
#   'or',
#   'MATH',
#   '142B',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisite',
#   's',
#   'may',
#   'enroll',
#   'with',
#   'the',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '20E',
#   'and',
#   'either',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '150A', 'or', 'consent', 'of', 'instructor'],
#  ['span',
#   'MATH',
#   '20D',
#   'and',
#   'either',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '109', 'or', 'MATH', '31CH,', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '155A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['em',
#   'strong',
#   'strong',
#   'MATH',
#   '20D',
#   'and',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '100A,',
#   'or',
#   'MATH',
#   '103A,',
#   'or',
#   'MATH',
#   '140A,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '160A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '20B', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '170A'],
#  ['MATH',
#   '20D',
#   'or',
#   '21D',
#   'and',
#   'MATH',
#   '170B,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '171A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '20C',
#   'or',
#   'MATH',
#   '31BH',
#   'and',
#   'MATH',
#   '20F',
#   'or',
#   '31AH',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '173A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['Math',
#   '20D',
#   'or',
#   'MATH',
#   '21D,',
#   'and',
#   'either',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '174', 'or', 'MATH', '274,', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '174', 'or', 'MATH', '274', 'or', 'consent', 'of', 'instructor'],
#  ['span',
#   'Math',
#   '20C',
#   'or',
#   'MATH',
#   '31BH,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '20D',
#   'and',
#   'either',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '109',
#   'or',
#   'MATH',
#   '31CH,',
#   'and',
#   'MATH',
#   '180A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '180B', 'or', 'consent', 'of', 'instructor'],
#  ['span',
#   'MATH',
#   '180A,',
#   'and',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '181A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '181B', 'or', 'consent', 'of', 'instructor'],
#  ['strong',
#   'ECE',
#   '109',
#   'or',
#   'ECON',
#   '120A',
#   'or',
#   'MAE',
#   '108',
#   'or',
#   'MATH',
#   '181A',
#   'or',
#   'MATH',
#   '183',
#   'or',
#   'MATH',
#   '186',
#   'or',
#   'MATH',
#   '189',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '181B', 'or', 'consent', 'of', 'instructor'],
#  ['strong',
#   'ECE',
#   '109',
#   'or',
#   'ECON',
#   '120A',
#   'or',
#   'MAE',
#   '108',
#   'or',
#   'MATH',
#   '11',
#   'or',
#   'MATH',
#   '181A',
#   'or',
#   'MATH',
#   '183',
#   'or',
#   'MATH',
#   '186',
#   'or',
#   'MATH',
#   '189',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['span',
#   'MATH',
#   '20C',
#   'or',
#   'MATH',
#   '31BH,',
#   'or',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['span',
#   'MATH',
#   '11,',
#   'or',
#   'MATH',
#   '181A,',
#   'or',
#   'MATH',
#   '183,',
#   'or',
#   'MATH',
#   '186,',
#   'or',
#   'MAE',
#   '108,',
#   'or',
#   'ECE',
#   '109,',
#   'or',
#   'ECON',
#   '120A,',
#   'and',
#   'either',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '20C', 'or', 'MATH', '31BH,', 'or', 'consent', 'of', 'instructor'],
#  ['none'],
#  ['MATH',
#   '187',
#   'or',
#   'MATH',
#   '187A',
#   'and',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '31AH',
#   'or',
#   'MATH',
#   '20F',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '109',
#   'and',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '31AH',
#   'and',
#   'MATH',
#   '100A',
#   'or',
#   '103A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '20C',
#   'and',
#   'one',
#   'of',
#   'BENG',
#   '134,',
#   'CSE',
#   '103,',
#   'ECE',
#   '109,',
#   'ECON',
#   '120A,',
#   'MAE',
#   '108,',
#   'MATH',
#   '180A,',
#   'MATH',
#   '183,',
#   'MATH',
#   '186,',
#   'or',
#   'SE',
#   '125',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['em',
#   'strong',
#   'strong',
#   'MATH',
#   '31CH',
#   'or',
#   'MATH',
#   '140A',
#   'or',
#   'MATH',
#   '142A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['strong',
#   'MATH',
#   '190A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'the',
#   'listed',
#   'prerequisite',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'],
#  ['MATH', '190', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '180A', 'or', 'MATH', '183,', 'or', 'consent', 'of', 'instructor'],
#  ['MATH', '193A', 'or', 'consent', 'of', 'instructor'],
#  ['MATH',
#   '20D,',
#   'and',
#   'either',
#   'MATH',
#   '18',
#   'or',
#   'MATH',
#   '20F',
#   'or',
#   'MATH',
#   '31AH,',
#   'and',
#   'MATH',
#   '180A',
#   'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor',
#   'Students',
#   'completing',
#   'ECON',
#   '120A',
#   'instead',
#   'of',
#   'MATH',
#   '180A',
#   'must',
#   'obtain',
#   'consent',
#   'of',
#   'instructor',
#   'to',
#   'enroll'],
#  ['consent', 'of', 'instructor'],
#  ['upper', 'division', 'status'],
#  ['completion',
#   'of',
#   'ninety',
#   'units,',
#   'two',
#   'upper',
#   'division',
#   'mathematics',
#   'courses,',
#   'an',
#   'overall',
#   '2',
#   '5',
#   'UC',
#   'San',
#   'Diego',
#   'GPA,',
#   'consent',
#   'of',
#   'mathematics',
#   'faculty',
#   'coordinator,',
#   'and',
#   'submission',
#   'of',
#   'written',
#   'contract',
#   'Department',
#   'stamp',
#   'required'],
#  ['permission', 'of', 'department'],
#  ['admission',
#   'to',
#   'the',
#   'Honors',
#   'Program',
#   'in',
#   'mathematics,',
#   'department',
#   'stamp']]

# %% [markdown]
# ## Check where the ValueErrors occur!  In some cases it may be faulty html e.g Math 157 has weird indent and misses prereq section

# %% [markdown]
# Before cell below, need to clear the following words/strings:
# 'either'
#
# and turn this:
#
# 'Students',
#   'who',
#   'have',
#   'not',
#   'completed',
#   'listed',
#   'prerequisites',
#   'may',
#   'enroll',
#   'with',
#   'consent',
#   'of',
#   'instructor'
#
# into just " or + consent of instructor"

# %% [markdown]
# ### might have to parse for or and make the lists 3d

# %%
prereqs_2d = []
for n in np.arange(len(course_ids)):
    ps = prereq_list[n]
    ps_2d = [[]]
    inner_i = 0
    for i in np.arange(len(ps)):    
        if ps[i] != 'and':
            ps_2d[inner_i].append(ps[i])
        #if ps[i] == 'students' or 
        else:
            ps_2d.append([])
            inner_i = inner_i + 1
    prereqs_2d.append(ps_2d)

# %%
course_ids.index('100A')
# Out:
# 21

# %%
prereqs_2d[45]
# Out:
# [['MATH', '140A', 'or', 'consent', 'of', 'instructor']]

# %% [markdown]
# all classes are going to have to be in the same object unless more looping

# %%
for prereq in prereqs_for_some_class:
    preprereqs = [] # prereqs for this prereq 
    look at prereqs of the prereq:
        repeat?


for i in prereqs:
    prereqs_3d[course_ids.index(i)]
# Out:
#   File "<ipython-input-23-889b7b9f37a0>", line 3
#     look at prereqs of the prereq:
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Want to create dataframe with Columns: name, ID, prereqs, descs (?)

# %%
course_info_df = pd.DataFrame({'Course id': course_ids, 'Course name': course_names, 'Course units' = course_units, 'Prereqs' = })

# %% [markdown]
# Course names array must be in 2d.
#
# [[Math 2, Introduction to College Mathematics], [MATH 3, Precalculus] ...]

# %%
#course_page = course_page[0:int(np.where(course_page == '<p class="course-name">MATH 200A-B-C. Algebra (4-4-4)</p>')[0])]
# Out:
# (205,)

# %%
courses = []
start = ' <p class="course-name"> '
stop = '</p>'
for i in course_page:
    for s in i:
# Out:
#   File "<ipython-input-51-89e5bcb3f799>", line 5
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # GRAPHS
#
# adjacency matrix or array of vertex pairs?
#
# -adj lists

# %% [markdown]
# have to consider inter departmental case and how to access their respective course_ids etc

# %% [markdown]
# The loop should keep going as long as it can find the class in a prereq object.
#
# dictionaries?  [Dept, ID] : [prereqs]

# %%
eg_prq = [['CSE 8B', 'CSE 11'],  ['MATH 18', 'MATH 31AH'], ['MATH 20E'], ['MATH 180A']]

for i in eg_prq:
    for n in eg_prq[i]:
        #dept = n[0][0]
                
                if eg_prq[i] == prereq_list[x]
